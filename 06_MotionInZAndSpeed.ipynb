# %%
import sys
import numpy as np
import os
from tifffile import imread, imwrite
import matplotlib.pyplot as plt
import napari
import napatrackmater.bTrackmate as TM
from pathlib import Path
# %gui qt

# %%
#Trackmate writes an XML file of tracks, we use it as input
xml_path = '/Users/aimachine/CBIAS-Demo/Results/DUP_Cell.xml' 
#Trackmate writes a spots and tracks file as csv
spot_csv = '/Users/aimachine/CBIAS-Demo/Results/spots.csv'
links_csv = '/Users/aimachine/CBIAS-Demo/Results/links.csv'
savedir = '/Users/aimachine/CBIAS-Demo/Results/'
Path(savedir).mkdir(exist_ok=True)

# %%
TM.import_TM_XML_statplots(xml_path,spot_csv, links_csv, savedir)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 73/73 [00:00<00:00, 779.24it/s]
